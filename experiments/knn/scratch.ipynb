# %%
from glassboxml.data.generators import generate_classification_dataset

# %%
X, y, w_true, b_true = generate_classification_dataset([1.5, 2.0, 0.4, 0.1])

# %%
from glassboxml.models.knn import KNN
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.33, random_state=42)

# %%
model = KNN(5)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

# %%
from glassboxml.metrics.classification import accuracy

accuracy(y_test, y_pred)
# Out:
# np.float64(0.9545454545454546)

# %%
import numpy as np
X = np.array([[0.0],[0.1],[0.2], [5.0],[5.1],[5.2], [10.0],[10.1],[10.2]])
y = np.array([0,0,0, 1,1,1, 2,2,2])

model = KNN(k=3)
model.fit(X, y)
print('predictions on training data:', model.predict(X))
print('expected:                    ', y)
# Out:
# predictions on training data: [0 0 0 1 1 1 2 2 2]
# expected:                     [0 0 0 1 1 1 2 2 2]

# %%
X_sample = np.array([[1,1,1], [1,4,5], [3,2,1]])
x = np.array([0,0,0])

np.linalg.norm(X_sample - x, axis=1)
# Out:
# array([1.73205081, 6.4807407 , 3.74165739])

# %%
from glassboxml.models.knn import KNNClassifier
import numpy as np

X = np.array([0.0, 0.1, 0.2,  5.1, 5.2, 5.5,  10.245, 11, 12.5])
y = np.array([0, 0, 0,  1, 1, 1,  2, 2, 2])

model = KNNClassifier(k = 3)
model.fit(X,y)

y_pred = model.predict(X)
# Out:
# ---------------------------------------------------------------------------
# AxisError                                 Traceback (most recent call last)
# Cell In[2], line 10
#       7 model = KNNClassifier(k = 3)
#       8 model.fit(X,y)
# ---> 10 y_pred = model.predict(X)
#
# File ~/GlassBoxML/glassboxml/models/knn.py:13, in _KNNBase.predict(self, X)
#      12 def predict(self, X):
# ---> 13     return np.array([self._predict_sample(x) for x in np.array(X)])
#
# File ~/GlassBoxML/glassboxml/models/knn.py:13, in <listcomp>(.0)
#      12 def predict(self, X):
# ---> 13     return np.array([self._predict_sample(x) for x in np.array(X)])
#
# File ~/GlassBoxML/glassboxml/models/knn.py:37, in KNNClassifier._predict_sample(self, x)
#      36 def _predict_sample(self, x):
# ---> 37     k_labels = self._k_nearest_labels(x)
#      38     return Counter(k_labels).most_common(1)[0][0]
#
# File ~/GlassBoxML/glassboxml/models/knn.py:17, in _KNNBase._k_nearest_labels(self, x)
#      15 def _k_nearest_labels(self, x):
#      16     #Use vectorized calculations for calculating distances
# ---> 17     distances = np.linalg.norm(self.X_train - x, axis=1)
#      19     # argpartition(distances, k) needs an extra element past the k we
#      20     # keep to anchor the partition, so it only works for k < n_samples.
#      21     # If k covers the whole training set (or more), there's nothing to
#      22     # partition - every point is a "k nearest" neighbour.
#      23     if self.k >= len(distances):
#
# File ~/GlassBoxML/.venv/lib/python3.11/site-packages/numpy/linalg/_linalg.py:2804, in norm(x, ord, axis, keepdims)
#    2801 elif ord is None or ord == 2:
#    2802     # special case for speedup
#    2803     s = (x.conj() * x).real
# -> 2804     return sqrt(add.reduce(s, axis=axis, keepdims=keepdims))
#    2805 # None of the str-type keywords for ord ('fro', 'nuc')
#    2806 # are valid for vectors
#    2807 elif isinstance(ord, str):
#
# AxisError: axis 1 is out of bounds for array of dimension 1
